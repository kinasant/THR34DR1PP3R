# %%
n1=...
n2=...
c1=...
c2=...

# %%
bin(n2)[-314:]
# Out:
# ''

# %%
int('',2)
# Out:
# 30103402703776243064017811439557711059290669207509918507155982967151908999721221722233453121175

# %%
#factored from https://www.alpertron.com.ar/ECM.HTM
a1=int("1 651764 208712 002362 909070 586532 659043 033781 575172 011989 418709 627827 265240 039573 208353 001543".replace(" ",''))

# %%
a1
# Out:
# 1651764208712002362909070586532659043033781575172011989418709627827265240039573208353001543

# %%
n2 % a1
# Out:
# 0

# %%
a2 =  n2//a1

# %%
p2=sqrt(a2)

# %%
phin = (p2)*(p2-1)*(a1-1)

# %%
from Crypto.Util.number import *

# %%
long_to_bytes(pow(c2,pow(65537,-1,phin),n2))
# Out:
# b'DEAD{Rual_R0s4s_Chiweweiner!!}'
